# %%
import pandas as pd

# %%
df_org = pd.read_csv("COVID-19_Outcomes_by_Vaccination_Status_-_Historical.csv")
df = df_org.copy()

# %%
df.shape
# Out:
# (3753, 21)

# %%
df.columns
# Out:
# Index(['Outcome', 'Week End', 'Age Group', 'Unvaccinated Rate',
#        'Vaccinated Rate', 'Boosted Rate', 'Crude Vaccinated Ratio',
#        'Crude Boosted Ratio', 'Age-Adjusted Unvaccinated Rate',
#        'Age-Adjusted Vaccinated Rate', 'Age-Adjusted Boosted Rate',
#        'Age-Adjusted Vaccinated Ratio', 'Age-Adjusted Boosted Ratio',
#        'Population Unvaccinated', 'Population Vaccinated',
#        'Population Boosted', 'Outcome Unvaccinated', 'Outcome Vaccinated',
#        'Outcome Boosted', 'Age Group Min', 'Age Group Max'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Outcome                            object
# Week End                           object
# Age Group                          object
# Unvaccinated Rate                 float64
# Vaccinated Rate                   float64
# Boosted Rate                      float64
# Crude Vaccinated Ratio            float64
# Crude Boosted Ratio               float64
# Age-Adjusted Unvaccinated Rate    float64
# Age-Adjusted Vaccinated Rate      float64
# Age-Adjusted Boosted Rate         float64
# Age-Adjusted Vaccinated Ratio     float64
# Age-Adjusted Boosted Ratio        float64
# Population Unvaccinated             int64
# Population Vaccinated             float64
# Population Boosted                float64
# Outcome Unvaccinated                int64
# Outcome Vaccinated                float64
# Outcome Boosted                   float64
# Age Group Min                       int64
# Age Group Max                       int64
# dtype: object

# %%
df.isnull().mean()*100
# Out:
# Outcome                            0.000000
# Week End                           0.000000
# Age Group                          0.000000
# Unvaccinated Rate                  0.000000
# Vaccinated Rate                    8.713030
# Boosted Rate                      32.613909
# Crude Vaccinated Ratio            38.182787
# Crude Boosted Ratio               53.077538
# Age-Adjusted Unvaccinated Rate    88.888889
# Age-Adjusted Vaccinated Rate      88.888889
# Age-Adjusted Boosted Rate         91.207034
# Age-Adjusted Vaccinated Ratio     89.874767
# Age-Adjusted Boosted Ratio        91.686651
# Population Unvaccinated            0.000000
# Population Vaccinated             14.388489
# Population Boosted                32.613909
# Outcome Unvaccinated               0.000000
# Outcome Vaccinated                 8.713030
# Outcome Boosted                   32.613909
# Age Group Min                      0.000000
# Age Group Max                      0.000000
# dtype: float64

# %%
df.columns
# Out:
# Index(['Outcome', 'Week End', 'Age Group', 'Unvaccinated Rate',
#        'Vaccinated Rate', 'Boosted Rate', 'Crude Vaccinated Ratio',
#        'Crude Boosted Ratio', 'Age-Adjusted Unvaccinated Rate',
#        'Age-Adjusted Vaccinated Rate', 'Age-Adjusted Boosted Rate',
#        'Age-Adjusted Vaccinated Ratio', 'Age-Adjusted Boosted Ratio',
#        'Population Unvaccinated', 'Population Vaccinated',
#        'Population Boosted', 'Outcome Unvaccinated', 'Outcome Vaccinated',
#        'Outcome Boosted', 'Age Group Min', 'Age Group Max'],
#       dtype='object')

# %%
df = df.drop(columns=['Age-Adjusted Unvaccinated Rate','Age-Adjusted Vaccinated Rate',
    'Age-Adjusted Boosted Rate','Age-Adjusted Vaccinated Ratio', 
    'Age-Adjusted Boosted Ratio'])

# %%
def null_check():
    return df.isnull().mean()*100

# %%
null_check()
# Out:
# Outcome                     0.000000
# Week End                    0.000000
# Age Group                   0.000000
# Unvaccinated Rate           0.000000
# Vaccinated Rate             8.713030
# Boosted Rate               32.613909
# Crude Vaccinated Ratio     38.182787
# Crude Boosted Ratio        53.077538
# Population Unvaccinated     0.000000
# Population Vaccinated      14.388489
# Population Boosted         32.613909
# Outcome Unvaccinated        0.000000
# Outcome Vaccinated          8.713030
# Outcome Boosted            32.613909
# Age Group Min               0.000000
# Age Group Max               0.000000
# dtype: float64

# %% [markdown]
# # Checking skewness

# %%
def sk_check(data):
    skewness = data.skew()
    return skewness

# %% [markdown]
# # Handling missing data

# %%
print(sk_check(df['Vaccinated Rate']))
# Out:
# 8.560854597367811

# %%
df['Vaccinated Rate'] = df['Vaccinated Rate'].fillna(df['Vaccinated Rate'].median())

# %%
null_check()
# Out:
# Outcome                     0.000000
# Week End                    0.000000
# Age Group                   0.000000
# Unvaccinated Rate           0.000000
# Vaccinated Rate             0.000000
# Boosted Rate               32.613909
# Crude Vaccinated Ratio     38.182787
# Crude Boosted Ratio        53.077538
# Population Unvaccinated     0.000000
# Population Vaccinated      14.388489
# Population Boosted         32.613909
# Outcome Unvaccinated        0.000000
# Outcome Vaccinated          8.713030
# Outcome Boosted            32.613909
# Age Group Min               0.000000
# Age Group Max               0.000000
# dtype: float64

# %%
sk_check(df['Boosted Rate'])
# Out:
# np.float64(5.949102101742281)

# %%
df['Boosted Rate'] = df['Boosted Rate'].fillna(df['Boosted Rate'].median())

# %%
sk_check(df['Crude Boosted Ratio'])
# Out:
# np.float64(6.08337741867004)

# %%
df['Crude Boosted Ratio'] = df['Crude Boosted Ratio'].fillna(df['Crude Boosted Ratio'].median())

# %%
null_check()
# Out:
# Outcome                     0.000000
# Week End                    0.000000
# Age Group                   0.000000
# Unvaccinated Rate           0.000000
# Vaccinated Rate             0.000000
# Boosted Rate                0.000000
# Crude Vaccinated Ratio     38.182787
# Crude Boosted Ratio         0.000000
# Population Unvaccinated     0.000000
# Population Vaccinated      14.388489
# Population Boosted         32.613909
# Outcome Unvaccinated        0.000000
# Outcome Vaccinated          8.713030
# Outcome Boosted            32.613909
# Age Group Min               0.000000
# Age Group Max               0.000000
# dtype: float64

# %%
sk_check(df['Crude Vaccinated Ratio'])
# Out:
# np.float64(8.169698293472774)

# %%
df['Crude Vaccinated Ratio'] = df['Crude Vaccinated Ratio'].fillna(df['Crude Vaccinated Ratio'].median())

# %%
sk_check(df['Population Vaccinated'])
# Out:
# np.float64(2.1037433783115556)

# %%
df['Population Vaccinated'] = df['Population Vaccinated'].fillna(df['Population Vaccinated'].median())

# %%
null_check()
# Out:
# Outcome                     0.000000
# Week End                    0.000000
# Age Group                   0.000000
# Unvaccinated Rate           0.000000
# Vaccinated Rate             0.000000
# Boosted Rate                0.000000
# Crude Vaccinated Ratio      0.000000
# Crude Boosted Ratio         0.000000
# Population Unvaccinated     0.000000
# Population Vaccinated       0.000000
# Population Boosted         32.613909
# Outcome Unvaccinated        0.000000
# Outcome Vaccinated          8.713030
# Outcome Boosted            32.613909
# Age Group Min               0.000000
# Age Group Max               0.000000
# dtype: float64

# %%
sk_check(df['Population Boosted'])
# Out:
# np.float64(1.880259420028074)

# %%
df['Population Boosted'] = df['Population Boosted'].fillna(df['Population Boosted'].median())

# %%
null_check()
# Out:
# Outcome                     0.000000
# Week End                    0.000000
# Age Group                   0.000000
# Unvaccinated Rate           0.000000
# Vaccinated Rate             0.000000
# Boosted Rate                0.000000
# Crude Vaccinated Ratio      0.000000
# Crude Boosted Ratio         0.000000
# Population Unvaccinated     0.000000
# Population Vaccinated       0.000000
# Population Boosted          0.000000
# Outcome Unvaccinated        0.000000
# Outcome Vaccinated          8.713030
# Outcome Boosted            32.613909
# Age Group Min               0.000000
# Age Group Max               0.000000
# dtype: float64

# %%
sk_check(df['Outcome Vaccinated'])
# Out:
# np.float64(20.10891273749771)

# %%
df['Outcome Vaccinated'] = df['Outcome Vaccinated'].fillna(df['Outcome Vaccinated'].median())

# %%
sk_check(df['Outcome Boosted'])
# Out:
# np.float64(8.118304007395798)

# %%
df['Outcome Boosted'] = df['Outcome Boosted'].fillna(df['Outcome Boosted'].median())

# %%
null_check()
# Out:
# Outcome                    0.0
# Week End                   0.0
# Age Group                  0.0
# Unvaccinated Rate          0.0
# Vaccinated Rate            0.0
# Boosted Rate               0.0
# Crude Vaccinated Ratio     0.0
# Crude Boosted Ratio        0.0
# Population Unvaccinated    0.0
# Population Vaccinated      0.0
# Population Boosted         0.0
# Outcome Unvaccinated       0.0
# Outcome Vaccinated         0.0
# Outcome Boosted            0.0
# Age Group Min              0.0
# Age Group Max              0.0
# dtype: float64

# %%
df.dtypes
# Out:
# Outcome                     object
# Week End                    object
# Age Group                   object
# Unvaccinated Rate          float64
# Vaccinated Rate            float64
# Boosted Rate               float64
# Crude Vaccinated Ratio     float64
# Crude Boosted Ratio        float64
# Population Unvaccinated      int64
# Population Vaccinated      float64
# Population Boosted         float64
# Outcome Unvaccinated         int64
# Outcome Vaccinated         float64
# Outcome Boosted            float64
# Age Group Min                int64
# Age Group Max                int64
# dtype: object

# %%
df.head(1)
# Out:
#   Outcome    Week End Age Group  Unvaccinated Rate  Vaccinated Rate  \
# 0  Deaths  10/01/2022       All                0.3              0.1
#
#    Boosted Rate  Crude Vaccinated Ratio  Crude Boosted Ratio  \
# 0           0.9                     3.0                  0.3
#
#    Population Unvaccinated  Population Vaccinated  Population Boosted  \
# 0                   591822               842535.0           1037067.0
#
#    Outcome Unvaccinated  Outcome Vaccinated  Outcome Boosted  Age Group Min  \
# 0                     2                 1.0              9.0            999
#
#    Age Group Max
# 0            999

# %% [markdown]
# # Data Transfromation

# %%
df['Outcome'] = df['Outcome'].replace({
    'Deaths'  : 0 , 
    'Hospitalizations' : 1, 
    'Cases' : 2
})
# Out:
# C:\Users\Windows 11\AppData\Local\Temp\ipykernel_13640\4055734627.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Outcome'] = df['Outcome'].replace({

# %%
df['Outcome'].unique()
# Out:
# array([0, 1, 2])

# %%
df.columns
# Out:
# Index(['Outcome', 'Week End', 'Age Group', 'Unvaccinated Rate',
#        'Vaccinated Rate', 'Boosted Rate', 'Crude Vaccinated Ratio',
#        'Crude Boosted Ratio', 'Population Unvaccinated',
#        'Population Vaccinated', 'Population Boosted', 'Outcome Unvaccinated',
#        'Outcome Vaccinated', 'Outcome Boosted', 'Age Group Min',
#        'Age Group Max'],
#       dtype='object')

# %%
df['Week End'] = pd.to_datetime(df['Week End'])

df['Year'] = df['Week End'].dt.year
df['Month'] = df['Week End'].dt.month
df['Week'] = df['Week End'].dt.isocalendar().week

df = df.drop(columns=['Week End'])

# %% [markdown]
# ##### Lable encoding for age group

# %%
df['Age Group'].unique()
# Out:
# array(['All', '50-64', '5-11', '18-29', '12-17', '30-49', '80+', '65-79',
#        '0-4'], dtype=object)

# %%
# Droping (all)

df = df[df['Age Group'] != 'All']

# %%
df['Age Group'] = df['Age Group'].replace({'0-4' : 0 ,'5-11' : 1 , 
                                           '12-17' : 2 ,'18-29' : 3 ,
                                           '30-49' :  4 , '50-64' : 5 ,
                                           '65-79': 6, '80+' : 7})
# Out:
# C:\Users\Windows 11\AppData\Local\Temp\ipykernel_13640\710177977.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Age Group'] = df['Age Group'].replace({'0-4' : 0 ,'5-11' : 1 ,

# %%
df['Age Group'].unique()
# Out:
# array([5, 1, 3, 2, 4, 7, 6, 0])

# %%
df.dtypes
# Out:
# Outcome                      int64
# Age Group                    int64
# Unvaccinated Rate          float64
# Vaccinated Rate            float64
# Boosted Rate               float64
# Crude Vaccinated Ratio     float64
# Crude Boosted Ratio        float64
# Population Unvaccinated      int64
# Population Vaccinated      float64
# Population Boosted         float64
# Outcome Unvaccinated         int64
# Outcome Vaccinated         float64
# Outcome Boosted            float64
# Age Group Min                int64
# Age Group Max                int64
# Year                         int32
# Month                        int32
# Week                        UInt32
# dtype: object

# %% [markdown]
# # Outliers Handling

# %%
def detect_outliers_iqr(data):
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = data[(data < lower_bound) | (data > upper_bound)]
    return outliers

def remove_outliers_iqr(data):
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    clean_data = data[(data >= lower) & (data <= upper)]
    return clean_data

# %%
for i in df.columns:
    out = detect_outliers_iqr(df[i])  
    print(i, "-->", len(out), "outliers")
# Out:
# Outcome --> 0 outliers
# Age Group --> 0 outliers
# Unvaccinated Rate --> 405 outliers
# Vaccinated Rate --> 544 outliers
# Boosted Rate --> 618 outliers
# Crude Vaccinated Ratio --> 1012 outliers
# Crude Boosted Ratio --> 1411 outliers
# Population Unvaccinated --> 51 outliers
# Population Vaccinated --> 87 outliers
# Population Boosted --> 219 outliers
# Outcome Unvaccinated --> 462 outliers
# Outcome Vaccinated --> 557 outliers
# Outcome Boosted --> 567 outliers
# Age Group Min --> 0 outliers
# Age Group Max --> 417 outliers
# Year --> 0 outliers
# Month --> 0 outliers
# Week --> 0 outliers

# %%
print(f"Rows before: {len(df)}")

skip_cols = ['Outcome', 'Age Group', 'Year', 'Month', 'Week', 
             'Age Group Min', 'Age Group Max']

numeric_cols = [col for col in df.select_dtypes(
    include=['float64', 'int64', 'int32', 'UInt32']).columns 
    if col not in skip_cols]

# Cap outliers instead of removing rows
for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    df[col] = df[col].clip(lower=lower, upper=upper)

print(f"Rows after: {len(df)}")
print("✅ Outliers capped!")
# Out:
# Rows before: 3336
# Rows after: 3336
# ✅ Outliers capped!

# %%
df.to_csv("Cleaned Covid 19_Vac_Status.csv", index=False)

# %%
print(df.shape)
print(df.isnull().sum().sum())
print(df.dtypes.value_counts())
# Out:
# (3336, 18)
# 0
# float64    9
# int64      6
# int32      2
# UInt32     1
# Name: count, dtype: int64
